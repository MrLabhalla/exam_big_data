# %%
from kafka import KafkaConsumer
import json
from json import loads

TOPIC_NAME = "sinkTopic"
consumer = KafkaConsumer(
    'Data_MachineIOT',
     bootstrap_servers=['localhost:9092'],
     auto_offset_reset='earliest',
     enable_auto_commit=True,
     group_id='Data_MachineIOT',
     value_deserializer=lambda x: loads(x.decode('utf-8')))

# %%
from kafka import KafkaConsumer
from pymongo import MongoClient
from json import loads

client = MongoClient('localhost:27017')
collection = client.numtest.numtest

consumer = KafkaConsumer(
    'Data_Machines',
     bootstrap_servers=['localhost:9092'],
     auto_offset_reset='earliest',
     enable_auto_commit=True,
     value_deserializer=lambda x: loads(x.decode('utf-8')))

for message in consumer:
    message1 = message.value
    #collection.insert_one(message)
    print(message1)
    #print('{} added to {}'.format(message, collection))
# Out:
# {'\ufeffUDI': '1', 'Product ID': 'M14860', 'Type': 'M', 'Air temperature [K]': '298.1', 'Process temperature [K]': '308.6', 'Rotational speed [rpm]': '1551', 'Torque [Nm]': '42.8', 'Tool wear [min]': '0', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '2', 'Product ID': 'L47181', 'Type': 'L', 'Air temperature [K]': '298.2', 'Process temperature [K]': '308.7', 'Rotational speed [rpm]': '1408', 'Torque [Nm]': '46.3', 'Tool wear [min]': '3', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '3', 'Product ID': 'L47182', 'Type': 'L', 'Air temperature [K]': '298.1', 'Process temperature [K]': '308.5', 'Rotational speed [rpm]': '1498', 'Torque [Nm]': '49.4', 'Tool wear [min]': '5', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '4', 'Product ID': 'L47183', 'Type': 'L', 'Air temperature [K]': '298.2', 'Process temperature [K]': '308.6', 'Rotational speed [rpm]': '1433', 'Torque [Nm]': '39.5', 'Tool wear [min]': '7', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '5', 'Product ID': 'L47184', 'Type': 'L', 'Air temperature [K]': '298.2', 'Process temperature [K]': '308.7', 'Rotational speed [rpm]': '1408', 'Torque [Nm]': '40', 'Tool wear [min]': '9', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '6', 'Product ID': 'M14865', 'Type': 'M', 'Air temperature [K]': '298.1', 'Process temperature [K]': '308.6', 'Rotational speed [rpm]': '1425', 'Torque [Nm]': '41.9', 'Tool wear [min]': '11', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '7', 'Product ID': 'L47186', 'Type': 'L', 'Air temperature [K]': '298.1', 'Process temperature [K]': '308.6', 'Rotational speed [rpm]': '1558', 'Torque [Nm]': '42.4', 'Tool wear [min]': '14', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '8', 'Product ID': 'L47187', 'Type': 'L', 'Air temperature [K]': '298.1', 'Process temperature [K]': '308.6', 'Rotational speed [rpm]': '1527', 'Torque [Nm]': '40.2', 'Tool wear [min]': '16', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '9', 'Product ID': 'M14868', 'Type': 'M', 'Air temperature [K]': '298.3', 'Process temperature [K]': '308.7', 'Rotational speed [rpm]': '1667', 'Torque [Nm]': '28.6', 'Tool wear [min]': '18', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '10', 'Product ID': 'M14869', 'Type': 'M', 'Air temperature [K]': '298.5', 'Process temperature [K]': '309', 'Rotational speed [rpm]': '1741', 'Torque [Nm]': '28', 'Tool wear [min]': '21', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '11', 'Product ID': 'H29424', 'Type': 'H', 'Air temperature [K]': '298.4', 'Process temperature [K]': '308.9', 'Rotational speed [rpm]': '1782', 'Torque [Nm]': '23.9', 'Tool wear [min]': '24', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '12', 'Product ID': 'H29425', 'Type': 'H', 'Air temperature [K]': '298.6', 'Process temperature [K]': '309.1', 'Rotational speed [rpm]': '1423', 'Torque [Nm]': '44.3', 'Tool wear [min]': '29', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '13', 'Product ID': 'M14872', 'Type': 'M', 'Air temperature [K]': '298.6', 'Process temperature [K]': '309.1', 'Rotational speed [rpm]': '1339', 'Torque [Nm]': '51.1', 'Tool wear [min]': '34', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '14', 'Product ID': 'M14873', 'Type': 'M', 'Air temperature [K]': '298.6', 'Process temperature [K]': '309.2', 'Rotational speed [rpm]': '1742', 'Torque [Nm]': '30', 'Tool wear [min]': '37', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '15', 'Product ID': 'L47194', 'Type': 'L', 'Air temperature [K]': '298.6', 'Process temperature [K]': '309.2', 'Rotational speed [rpm]': '2035', 'Torque [Nm]': '19.6', 'Tool wear [min]': '40', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '16', 'Product ID': 'L47195', 'Type': 'L', 'Air temperature [K]': '298.6', 'Process temperature [K]': '309.2', 'Rotational speed [rpm]': '1542', 'Torque [Nm]': '48.4', 'Tool wear [min]': '42', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '17', 'Product ID': 'M14876', 'Type': 'M', 'Air temperature [K]': '298.6', 'Process temperature [K]': '309.2', 'Rotational speed [rpm]': '1311', 'Torque [Nm]': '46.6', 'Tool wear [min]': '44', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '18', 'Product ID': 'M14877', 'Type': 'M', 'Air temperature [K]': '298.7', 'Process temperature [K]': '309.2', 'Rotational speed [rpm]': '1410', 'Torque [Nm]': '45.6', 'Tool wear [min]': '47', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '19', 'Product ID': 'H29432', 'Type': 'H', 'Air temperature [K]': '298.8', 'Process temperature [K]': '309.2', 'Rotational speed [rpm]': '1306', 'Torque [Nm]': '54.5', 'Tool wear [min]': '50', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '20', 'Product ID': 'M14879', 'Type': 'M', 'Air temperature [K]': '298.9', 'Process temperature [K]': '309.3', 'Rotational speed [rpm]': '1632', 'Torque [Nm]': '32.5', 'Tool wear [min]': '55', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '21', 'Product ID': 'H29434', 'Type': 'H', 'Air temperature [K]': '298.9', 'Process temperature [K]': '309.3', 'Rotational speed [rpm]': '1375', 'Torque [Nm]': '42.7', 'Tool wear [min]': '58', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '22', 'Product ID': 'L47201', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '309.3', 'Rotational speed [rpm]': '1450', 'Torque [Nm]': '44.8', 'Tool wear [min]': '63', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '23', 'Product ID': 'M14882', 'Type': 'M', 'Air temperature [K]': '298.9', 'Process temperature [K]': '309.3', 'Rotational speed [rpm]': '1581', 'Torque [Nm]': '30.7', 'Tool wear [min]': '65', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '24', 'Product ID': 'L47203', 'Type': 'L', 'Air temperature [K]': '299', 'Process temperature [K]': '309.4', 'Rotational speed [rpm]': '1758', 'Torque [Nm]': '25.7', 'Tool wear [min]': '68', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '25', 'Product ID': 'M14884', 'Type': 'M', 'Air temperature [K]': '299', 'Process temperature [K]': '309.4', 'Rotational speed [rpm]': '1561', 'Torque [Nm]': '37.3', 'Tool wear [min]': '70', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '26', 'Product ID': 'L47205', 'Type': 'L', 'Air temperature [K]': '299', 'Process temperature [K]': '309.5', 'Rotational speed [rpm]': '1861', 'Torque [Nm]': '23.3', 'Tool wear [min]': '73', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '27', 'Product ID': 'L47206', 'Type': 'L', 'Air temperature [K]': '299.1', 'Process temperature [K]': '309.5', 'Rotational speed [rpm]': '1512', 'Torque [Nm]': '39', 'Tool wear [min]': '75', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '28', 'Product ID': 'H29441', 'Type': 'H', 'Air temperature [K]': '299.1', 'Process temperature [K]': '309.4', 'Rotational speed [rpm]': '1811', 'Torque [Nm]': '24.6', 'Tool wear [min]': '77', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '29', 'Product ID': 'L47208', 'Type': 'L', 'Air temperature [K]': '299.1', 'Process temperature [K]': '309.4', 'Rotational speed [rpm]': '1439', 'Torque [Nm]': '44.2', 'Tool wear [min]': '82', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '30', 'Product ID': 'L47209', 'Type': 'L', 'Air temperature [K]': '299', 'Process temperature [K]': '309.4', 'Rotational speed [rpm]': '1693', 'Torque [Nm]': '30.1', 'Tool wear [min]': '84', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '31', 'Product ID': 'M14890', 'Type': 'M', 'Air temperature [K]': '299.1', 'Process temperature [K]': '309.5', 'Rotational speed [rpm]': '1339', 'Torque [Nm]': '48.2', 'Tool wear [min]': '86', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '32', 'Product ID': 'L47211', 'Type': 'L', 'Air temperature [K]': '299', 'Process temperature [K]': '309.4', 'Rotational speed [rpm]': '1798', 'Torque [Nm]': '25.5', 'Tool wear [min]': '89', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '33', 'Product ID': 'L47212', 'Type': 'L', 'Air temperature [K]': '299', 'Process temperature [K]': '309.4', 'Rotational speed [rpm]': '1419', 'Torque [Nm]': '48.3', 'Tool wear [min]': '91', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '34', 'Product ID': 'L47213', 'Type': 'L', 'Air temperature [K]': '298.9', 'Process temperature [K]': '309.3', 'Rotational speed [rpm]': '1665', 'Torque [Nm]': '32.5', 'Tool wear [min]': '93', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '35', 'Product ID': 'M14894', 'Type': 'M', 'Air temperature [K]': '298.8', 'Process temperature [K]': '309.1', 'Rotational speed [rpm]': '1559', 'Torque [Nm]': '34.7', 'Tool wear [min]': '95', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '36', 'Product ID': 'M14895', 'Type': 'M', 'Air temperature [K]': '298.8', 'Process temperature [K]': '309.2', 'Rotational speed [rpm]': '1452', 'Torque [Nm]': '48.6', 'Tool wear [min]': '98', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '37', 'Product ID': 'M14896', 'Type': 'M', 'Air temperature [K]': '298.9', 'Process temperature [K]': '309.2', 'Rotational speed [rpm]': '1581', 'Torque [Nm]': '36.7', 'Tool wear [min]': '101', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '38', 'Product ID': 'L47217', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '309.1', 'Rotational speed [rpm]': '1439', 'Torque [Nm]': '39.2', 'Tool wear [min]': '104', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '39', 'Product ID': 'H29452', 'Type': 'H', 'Air temperature [K]': '298.9', 'Process temperature [K]': '309.2', 'Rotational speed [rpm]': '1379', 'Torque [Nm]': '50.7', 'Tool wear [min]': '106', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '40', 'Product ID': 'L47219', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '309.1', 'Rotational speed [rpm]': '1350', 'Torque [Nm]': '52.5', 'Tool wear [min]': '111', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '41', 'Product ID': 'L47220', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '309.1', 'Rotational speed [rpm]': '1362', 'Torque [Nm]': '45.4', 'Tool wear [min]': '113', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '42', 'Product ID': 'L47221', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '309.1', 'Rotational speed [rpm]': '1368', 'Torque [Nm]': '50.8', 'Tool wear [min]': '115', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '43', 'Product ID': 'M14902', 'Type': 'M', 'Air temperature [K]': '298.8', 'Process temperature [K]': '309.1', 'Rotational speed [rpm]': '1368', 'Torque [Nm]': '49.1', 'Tool wear [min]': '117', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '44', 'Product ID': 'H29457', 'Type': 'H', 'Air temperature [K]': '298.8', 'Process temperature [K]': '309.2', 'Rotational speed [rpm]': '1372', 'Torque [Nm]': '48.5', 'Tool wear [min]': '120', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '45', 'Product ID': 'M14904', 'Type': 'M', 'Air temperature [K]': '298.8', 'Process temperature [K]': '309.1', 'Rotational speed [rpm]': '1472', 'Torque [Nm]': '47.5', 'Tool wear [min]': '125', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '46', 'Product ID': 'L47225', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '309.1', 'Rotational speed [rpm]': '1489', 'Torque [Nm]': '49.1', 'Tool wear [min]': '128', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '47', 'Product ID': 'M14906', 'Type': 'M', 'Air temperature [K]': '298.7', 'Process temperature [K]': '309', 'Rotational speed [rpm]': '1843', 'Torque [Nm]': '25.8', 'Tool wear [min]': '130', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '48', 'Product ID': 'L47227', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '309.1', 'Rotational speed [rpm]': '1418', 'Torque [Nm]': '46.3', 'Tool wear [min]': '133', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '49', 'Product ID': 'H29462', 'Type': 'H', 'Air temperature [K]': '298.8', 'Process temperature [K]': '309.2', 'Rotational speed [rpm]': '1425', 'Torque [Nm]': '53.9', 'Tool wear [min]': '135', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '50', 'Product ID': 'M14909', 'Type': 'M', 'Air temperature [K]': '298.9', 'Process temperature [K]': '309.2', 'Rotational speed [rpm]': '1412', 'Torque [Nm]': '44.1', 'Tool wear [min]': '140', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '51', 'Product ID': 'L47230', 'Type': 'L', 'Air temperature [K]': '298.9', 'Process temperature [K]': '309.1', 'Rotational speed [rpm]': '2861', 'Torque [Nm]': '4.6', 'Tool wear [min]': '143', 'Target': '1', 'Failure Type': 'Power Failure'}
# {'\ufeffUDI': '52', 'Product ID': 'L47231', 'Type': 'L', 'Air temperature [K]': '298.9', 'Process temperature [K]': '309.1', 'Rotational speed [rpm]': '1383', 'Torque [Nm]': '54.9', 'Tool wear [min]': '145', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '53', 'Product ID': 'H29466', 'Type': 'H', 'Air temperature [K]': '298.8', 'Process temperature [K]': '309', 'Rotational speed [rpm]': '1497', 'Torque [Nm]': '43.8', 'Tool wear [min]': '147', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '54', 'Product ID': 'L47233', 'Type': 'L', 'Air temperature [K]': '298.7', 'Process temperature [K]': '309', 'Rotational speed [rpm]': '1565', 'Torque [Nm]': '35.1', 'Tool wear [min]': '152', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '55', 'Product ID': 'L47234', 'Type': 'L', 'Air temperature [K]': '298.7', 'Process temperature [K]': '309', 'Rotational speed [rpm]': '1691', 'Torque [Nm]': '30.1', 'Tool wear [min]': '154', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '56', 'Product ID': 'L47235', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '309.1', 'Rotational speed [rpm]': '1512', 'Torque [Nm]': '40.7', 'Tool wear [min]': '156', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '57', 'Product ID': 'L47236', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '309.1', 'Rotational speed [rpm]': '1477', 'Torque [Nm]': '42.4', 'Tool wear [min]': '158', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '58', 'Product ID': 'L47237', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '309.1', 'Rotational speed [rpm]': '1513', 'Torque [Nm]': '40.3', 'Tool wear [min]': '160', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '59', 'Product ID': 'M14918', 'Type': 'M', 'Air temperature [K]': '298.8', 'Process temperature [K]': '309', 'Rotational speed [rpm]': '1661', 'Torque [Nm]': '29.5', 'Tool wear [min]': '162', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '60', 'Product ID': 'L47239', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '309.1', 'Rotational speed [rpm]': '1378', 'Torque [Nm]': '54.4', 'Tool wear [min]': '165', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '61', 'Product ID': 'L47240', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '309.1', 'Rotational speed [rpm]': '1393', 'Torque [Nm]': '52.6', 'Tool wear [min]': '167', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '62', 'Product ID': 'M14921', 'Type': 'M', 'Air temperature [K]': '298.8', 'Process temperature [K]': '309', 'Rotational speed [rpm]': '1592', 'Torque [Nm]': '38.2', 'Tool wear [min]': '169', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '63', 'Product ID': 'L47242', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '309', 'Rotational speed [rpm]': '1829', 'Torque [Nm]': '22.9', 'Tool wear [min]': '172', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '64', 'Product ID': 'M14923', 'Type': 'M', 'Air temperature [K]': '298.9', 'Process temperature [K]': '309', 'Rotational speed [rpm]': '1812', 'Torque [Nm]': '25.9', 'Tool wear [min]': '174', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '65', 'Product ID': 'L47244', 'Type': 'L', 'Air temperature [K]': '299', 'Process temperature [K]': '309.1', 'Rotational speed [rpm]': '1523', 'Torque [Nm]': '38.6', 'Tool wear [min]': '177', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '66', 'Product ID': 'L47245', 'Type': 'L', 'Air temperature [K]': '299', 'Process temperature [K]': '309.1', 'Rotational speed [rpm]': '1394', 'Torque [Nm]': '45.1', 'Tool wear [min]': '179', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '67', 'Product ID': 'M14926', 'Type': 'M', 'Air temperature [K]': '298.9', 'Process temperature [K]': '308.9', 'Rotational speed [rpm]': '1679', 'Torque [Nm]': '28.7', 'Tool wear [min]': '181', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '68', 'Product ID': 'H29481', 'Type': 'H', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.9', 'Rotational speed [rpm]': '1466', 'Torque [Nm]': '44.1', 'Tool wear [min]': '184', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '69', 'Product ID': 'L47248', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.9', 'Rotational speed [rpm]': '1527', 'Torque [Nm]': '32.4', 'Tool wear [min]': '189', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '70', 'Product ID': 'L47249', 'Type': 'L', 'Air temperature [K]': '298.9', 'Process temperature [K]': '309', 'Rotational speed [rpm]': '1410', 'Torque [Nm]': '65.7', 'Tool wear [min]': '191', 'Target': '1', 'Failure Type': 'Power Failure'}
# {'\ufeffUDI': '71', 'Product ID': 'M14930', 'Type': 'M', 'Air temperature [K]': '298.9', 'Process temperature [K]': '309', 'Rotational speed [rpm]': '1924', 'Torque [Nm]': '22.6', 'Tool wear [min]': '193', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '72', 'Product ID': 'L47251', 'Type': 'L', 'Air temperature [K]': '298.9', 'Process temperature [K]': '309.1', 'Rotational speed [rpm]': '1452', 'Torque [Nm]': '45.5', 'Tool wear [min]': '196', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '73', 'Product ID': 'L47252', 'Type': 'L', 'Air temperature [K]': '298.9', 'Process temperature [K]': '309.1', 'Rotational speed [rpm]': '1369', 'Torque [Nm]': '44.4', 'Tool wear [min]': '198', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '74', 'Product ID': 'L47253', 'Type': 'L', 'Air temperature [K]': '299', 'Process temperature [K]': '309.1', 'Rotational speed [rpm]': '1592', 'Torque [Nm]': '35', 'Tool wear [min]': '200', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '75', 'Product ID': 'L47254', 'Type': 'L', 'Air temperature [K]': '298.9', 'Process temperature [K]': '309', 'Rotational speed [rpm]': '1601', 'Torque [Nm]': '32.3', 'Tool wear [min]': '202', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '76', 'Product ID': 'L47255', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.9', 'Rotational speed [rpm]': '1379', 'Torque [Nm]': '46.7', 'Tool wear [min]': '204', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '77', 'Product ID': 'L47256', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.9', 'Rotational speed [rpm]': '1461', 'Torque [Nm]': '47.9', 'Tool wear [min]': '206', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '78', 'Product ID': 'L47257', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.9', 'Rotational speed [rpm]': '1455', 'Torque [Nm]': '41.3', 'Tool wear [min]': '208', 'Target': '1', 'Failure Type': 'Tool Wear Failure'}
# {'\ufeffUDI': '79', 'Product ID': 'L47258', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.9', 'Rotational speed [rpm]': '1398', 'Torque [Nm]': '51.5', 'Tool wear [min]': '0', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '80', 'Product ID': 'L47259', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.9', 'Rotational speed [rpm]': '1402', 'Torque [Nm]': '37.9', 'Tool wear [min]': '2', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '81', 'Product ID': 'H29494', 'Type': 'H', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.8', 'Rotational speed [rpm]': '1445', 'Torque [Nm]': '49.9', 'Tool wear [min]': '4', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '82', 'Product ID': 'L47261', 'Type': 'L', 'Air temperature [K]': '298.9', 'Process temperature [K]': '308.9', 'Rotational speed [rpm]': '1450', 'Torque [Nm]': '47.5', 'Tool wear [min]': '9', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '83', 'Product ID': 'L47262', 'Type': 'L', 'Air temperature [K]': '298.9', 'Process temperature [K]': '308.9', 'Rotational speed [rpm]': '1453', 'Torque [Nm]': '40.8', 'Tool wear [min]': '11', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '84', 'Product ID': 'L47263', 'Type': 'L', 'Air temperature [K]': '299', 'Process temperature [K]': '309', 'Rotational speed [rpm]': '1469', 'Torque [Nm]': '40.1', 'Tool wear [min]': '13', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '85', 'Product ID': 'L47264', 'Type': 'L', 'Air temperature [K]': '298.9', 'Process temperature [K]': '308.9', 'Rotational speed [rpm]': '1422', 'Torque [Nm]': '47.6', 'Tool wear [min]': '15', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '86', 'Product ID': 'M14945', 'Type': 'M', 'Air temperature [K]': '299', 'Process temperature [K]': '309', 'Rotational speed [rpm]': '1804', 'Torque [Nm]': '26.8', 'Tool wear [min]': '17', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '87', 'Product ID': 'H29500', 'Type': 'H', 'Air temperature [K]': '299', 'Process temperature [K]': '309', 'Rotational speed [rpm]': '1436', 'Torque [Nm]': '43.9', 'Tool wear [min]': '20', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '88', 'Product ID': 'L47267', 'Type': 'L', 'Air temperature [K]': '299', 'Process temperature [K]': '309', 'Rotational speed [rpm]': '1544', 'Torque [Nm]': '31.8', 'Tool wear [min]': '25', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '89', 'Product ID': 'M14948', 'Type': 'M', 'Air temperature [K]': '299', 'Process temperature [K]': '309', 'Rotational speed [rpm]': '1419', 'Torque [Nm]': '45.2', 'Tool wear [min]': '27', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '90', 'Product ID': 'M14949', 'Type': 'M', 'Air temperature [K]': '298.9', 'Process temperature [K]': '308.9', 'Rotational speed [rpm]': '1487', 'Torque [Nm]': '39.5', 'Tool wear [min]': '30', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '91', 'Product ID': 'L47270', 'Type': 'L', 'Air temperature [K]': '298.9', 'Process temperature [K]': '308.9', 'Rotational speed [rpm]': '1753', 'Torque [Nm]': '25.8', 'Tool wear [min]': '33', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '92', 'Product ID': 'L47271', 'Type': 'L', 'Air temperature [K]': '298.9', 'Process temperature [K]': '308.9', 'Rotational speed [rpm]': '1830', 'Torque [Nm]': '24.9', 'Tool wear [min]': '35', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '93', 'Product ID': 'M14952', 'Type': 'M', 'Air temperature [K]': '298.9', 'Process temperature [K]': '308.9', 'Rotational speed [rpm]': '1727', 'Torque [Nm]': '27.1', 'Tool wear [min]': '37', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '94', 'Product ID': 'L47273', 'Type': 'L', 'Air temperature [K]': '299.1', 'Process temperature [K]': '309', 'Rotational speed [rpm]': '1450', 'Torque [Nm]': '43', 'Tool wear [min]': '40', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '95', 'Product ID': 'L47274', 'Type': 'L', 'Air temperature [K]': '299', 'Process temperature [K]': '308.9', 'Rotational speed [rpm]': '1622', 'Torque [Nm]': '31.9', 'Tool wear [min]': '42', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '96', 'Product ID': 'M14955', 'Type': 'M', 'Air temperature [K]': '299', 'Process temperature [K]': '309', 'Rotational speed [rpm]': '1351', 'Torque [Nm]': '52.2', 'Tool wear [min]': '44', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '97', 'Product ID': 'M14956', 'Type': 'M', 'Air temperature [K]': '299', 'Process temperature [K]': '309', 'Rotational speed [rpm]': '1575', 'Torque [Nm]': '35.3', 'Tool wear [min]': '47', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '98', 'Product ID': 'M14957', 'Type': 'M', 'Air temperature [K]': '298.9', 'Process temperature [K]': '308.9', 'Rotational speed [rpm]': '1750', 'Torque [Nm]': '29.9', 'Tool wear [min]': '50', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '99', 'Product ID': 'L47278', 'Type': 'L', 'Air temperature [K]': '298.9', 'Process temperature [K]': '308.8', 'Rotational speed [rpm]': '1529', 'Torque [Nm]': '32.7', 'Tool wear [min]': '53', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '100', 'Product ID': 'L47279', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.8', 'Rotational speed [rpm]': '1523', 'Torque [Nm]': '44.4', 'Tool wear [min]': '55', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '101', 'Product ID': 'L47280', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.9', 'Rotational speed [rpm]': '1852', 'Torque [Nm]': '25', 'Tool wear [min]': '57', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '102', 'Product ID': 'L47281', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.8', 'Rotational speed [rpm]': '1991', 'Torque [Nm]': '20.7', 'Tool wear [min]': '59', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '103', 'Product ID': 'L47282', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.8', 'Rotational speed [rpm]': '1555', 'Torque [Nm]': '40.6', 'Tool wear [min]': '61', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '104', 'Product ID': 'M14963', 'Type': 'M', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.8', 'Rotational speed [rpm]': '1441', 'Torque [Nm]': '40.5', 'Tool wear [min]': '63', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '105', 'Product ID': 'L47284', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.7', 'Rotational speed [rpm]': '1450', 'Torque [Nm]': '43.4', 'Tool wear [min]': '66', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '106', 'Product ID': 'L47285', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.7', 'Rotational speed [rpm]': '1591', 'Torque [Nm]': '31.1', 'Tool wear [min]': '68', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '107', 'Product ID': 'L47286', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.7', 'Rotational speed [rpm]': '1445', 'Torque [Nm]': '48.5', 'Tool wear [min]': '70', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '108', 'Product ID': 'M14967', 'Type': 'M', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.8', 'Rotational speed [rpm]': '1497', 'Torque [Nm]': '46.8', 'Tool wear [min]': '72', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '109', 'Product ID': 'H29522', 'Type': 'H', 'Air temperature [K]': '298.9', 'Process temperature [K]': '308.8', 'Rotational speed [rpm]': '1621', 'Torque [Nm]': '32.7', 'Tool wear [min]': '75', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '110', 'Product ID': 'L47289', 'Type': 'L', 'Air temperature [K]': '298.9', 'Process temperature [K]': '308.7', 'Rotational speed [rpm]': '1572', 'Torque [Nm]': '34.1', 'Tool wear [min]': '80', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '111', 'Product ID': 'L47290', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.6', 'Rotational speed [rpm]': '1872', 'Torque [Nm]': '22.5', 'Tool wear [min]': '82', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '112', 'Product ID': 'H29525', 'Type': 'H', 'Air temperature [K]': '298.7', 'Process temperature [K]': '308.6', 'Rotational speed [rpm]': '1499', 'Torque [Nm]': '43.5', 'Tool wear [min]': '84', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '113', 'Product ID': 'M14972', 'Type': 'M', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.7', 'Rotational speed [rpm]': '1498', 'Torque [Nm]': '39.5', 'Tool wear [min]': '89', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '114', 'Product ID': 'M14973', 'Type': 'M', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.6', 'Rotational speed [rpm]': '1486', 'Torque [Nm]': '41.9', 'Tool wear [min]': '92', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '115', 'Product ID': 'L47294', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.6', 'Rotational speed [rpm]': '1680', 'Torque [Nm]': '29.4', 'Tool wear [min]': '95', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '116', 'Product ID': 'L47295', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.6', 'Rotational speed [rpm]': '1431', 'Torque [Nm]': '45.7', 'Tool wear [min]': '97', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '117', 'Product ID': 'L47296', 'Type': 'L', 'Air temperature [K]': '298.9', 'Process temperature [K]': '308.7', 'Rotational speed [rpm]': '1564', 'Torque [Nm]': '34.1', 'Tool wear [min]': '99', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '118', 'Product ID': 'L47297', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.6', 'Rotational speed [rpm]': '1599', 'Torque [Nm]': '33', 'Tool wear [min]': '101', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '119', 'Product ID': 'M14978', 'Type': 'M', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.6', 'Rotational speed [rpm]': '1707', 'Torque [Nm]': '28.1', 'Tool wear [min]': '103', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '120', 'Product ID': 'L47299', 'Type': 'L', 'Air temperature [K]': '298.7', 'Process temperature [K]': '308.5', 'Rotational speed [rpm]': '1467', 'Torque [Nm]': '40.7', 'Tool wear [min]': '106', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '121', 'Product ID': 'L47300', 'Type': 'L', 'Air temperature [K]': '298.9', 'Process temperature [K]': '308.7', 'Rotational speed [rpm]': '1433', 'Torque [Nm]': '44.7', 'Tool wear [min]': '108', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '122', 'Product ID': 'L47301', 'Type': 'L', 'Air temperature [K]': '298.9', 'Process temperature [K]': '308.7', 'Rotational speed [rpm]': '1558', 'Torque [Nm]': '41.2', 'Tool wear [min]': '110', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '123', 'Product ID': 'L47302', 'Type': 'L', 'Air temperature [K]': '299', 'Process temperature [K]': '308.8', 'Rotational speed [rpm]': '1310', 'Torque [Nm]': '50.7', 'Tool wear [min]': '112', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '124', 'Product ID': 'L47303', 'Type': 'L', 'Air temperature [K]': '298.9', 'Process temperature [K]': '308.7', 'Rotational speed [rpm]': '1546', 'Torque [Nm]': '43.4', 'Tool wear [min]': '114', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '125', 'Product ID': 'L47304', 'Type': 'L', 'Air temperature [K]': '298.9', 'Process temperature [K]': '308.7', 'Rotational speed [rpm]': '1727', 'Torque [Nm]': '29.4', 'Tool wear [min]': '116', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '126', 'Product ID': 'L47305', 'Type': 'L', 'Air temperature [K]': '298.9', 'Process temperature [K]': '308.6', 'Rotational speed [rpm]': '1560', 'Torque [Nm]': '32.2', 'Tool wear [min]': '118', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '127', 'Product ID': 'L47306', 'Type': 'L', 'Air temperature [K]': '299', 'Process temperature [K]': '308.6', 'Rotational speed [rpm]': '1329', 'Torque [Nm]': '60.5', 'Tool wear [min]': '120', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '128', 'Product ID': 'L47307', 'Type': 'L', 'Air temperature [K]': '298.9', 'Process temperature [K]': '308.6', 'Rotational speed [rpm]': '1413', 'Torque [Nm]': '46.5', 'Tool wear [min]': '122', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '129', 'Product ID': 'L47308', 'Type': 'L', 'Air temperature [K]': '299', 'Process temperature [K]': '308.6', 'Rotational speed [rpm]': '1587', 'Torque [Nm]': '38.6', 'Tool wear [min]': '124', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '130', 'Product ID': 'L47309', 'Type': 'L', 'Air temperature [K]': '298.9', 'Process temperature [K]': '308.5', 'Rotational speed [rpm]': '1559', 'Torque [Nm]': '34.3', 'Tool wear [min]': '126', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '131', 'Product ID': 'L47310', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.4', 'Rotational speed [rpm]': '1473', 'Torque [Nm]': '41.1', 'Tool wear [min]': '128', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '132', 'Product ID': 'L47311', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.4', 'Rotational speed [rpm]': '1737', 'Torque [Nm]': '27.7', 'Tool wear [min]': '130', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '133', 'Product ID': 'M14992', 'Type': 'M', 'Air temperature [K]': '298.7', 'Process temperature [K]': '308.4', 'Rotational speed [rpm]': '1441', 'Torque [Nm]': '43.2', 'Tool wear [min]': '132', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '134', 'Product ID': 'M14993', 'Type': 'M', 'Air temperature [K]': '298.7', 'Process temperature [K]': '308.4', 'Rotational speed [rpm]': '1430', 'Torque [Nm]': '49.6', 'Tool wear [min]': '135', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '135', 'Product ID': 'L47314', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.4', 'Rotational speed [rpm]': '1369', 'Torque [Nm]': '53', 'Tool wear [min]': '138', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '136', 'Product ID': 'M14995', 'Type': 'M', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.5', 'Rotational speed [rpm]': '1711', 'Torque [Nm]': '28.5', 'Tool wear [min]': '140', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '137', 'Product ID': 'H29550', 'Type': 'H', 'Air temperature [K]': '298.7', 'Process temperature [K]': '308.5', 'Rotational speed [rpm]': '1420', 'Torque [Nm]': '45.7', 'Tool wear [min]': '143', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '138', 'Product ID': 'L47317', 'Type': 'L', 'Air temperature [K]': '298.7', 'Process temperature [K]': '308.6', 'Rotational speed [rpm]': '1297', 'Torque [Nm]': '55.3', 'Tool wear [min]': '148', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '139', 'Product ID': 'H29552', 'Type': 'H', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.6', 'Rotational speed [rpm]': '1449', 'Torque [Nm]': '49.4', 'Tool wear [min]': '150', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '140', 'Product ID': 'L47319', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.6', 'Rotational speed [rpm]': '1268', 'Torque [Nm]': '55.8', 'Tool wear [min]': '155', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '141', 'Product ID': 'L47320', 'Type': 'L', 'Air temperature [K]': '298.8', 'Process temperature [K]': '308.6', 'Rotational speed [rpm]': '1511', 'Torque [Nm]': '36.1', 'Tool wear [min]': '157', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '142', 'Product ID': 'L47321', 'Type': 'L', 'Air temperature [K]': '298.7', 'Process temperature [K]': '308.5', 'Rotational speed [rpm]': '1544', 'Torque [Nm]': '35.2', 'Tool wear [min]': '159', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '143', 'Product ID': 'M15002', 'Type': 'M', 'Air temperature [K]': '298.6', 'Process temperature [K]': '308.4', 'Rotational speed [rpm]': '1778', 'Torque [Nm]': '28.2', 'Tool wear [min]': '161', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '144', 'Product ID': 'H29557', 'Type': 'H', 'Air temperature [K]': '298.6', 'Process temperature [K]': '308.4', 'Rotational speed [rpm]': '1407', 'Torque [Nm]': '50.5', 'Tool wear [min]': '164', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '145', 'Product ID': 'M15004', 'Type': 'M', 'Air temperature [K]': '298.6', 'Process temperature [K]': '308.4', 'Rotational speed [rpm]': '1391', 'Torque [Nm]': '42.4', 'Tool wear [min]': '169', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '146', 'Product ID': 'L47325', 'Type': 'L', 'Air temperature [K]': '298.5', 'Process temperature [K]': '308.4', 'Rotational speed [rpm]': '1513', 'Torque [Nm]': '33.6', 'Tool wear [min]': '172', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '147', 'Product ID': 'H29560', 'Type': 'H', 'Air temperature [K]': '298.5', 'Process temperature [K]': '308.4', 'Rotational speed [rpm]': '1612', 'Torque [Nm]': '36.1', 'Tool wear [min]': '174', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '148', 'Product ID': 'L47327', 'Type': 'L', 'Air temperature [K]': '298.4', 'Process temperature [K]': '308.4', 'Rotational speed [rpm]': '1515', 'Torque [Nm]': '40.1', 'Tool wear [min]': '179', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '149', 'Product ID': 'M15008', 'Type': 'M', 'Air temperature [K]': '298.3', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1379', 'Torque [Nm]': '48', 'Tool wear [min]': '181', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '150', 'Product ID': 'L47329', 'Type': 'L', 'Air temperature [K]': '298.4', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1473', 'Torque [Nm]': '39.9', 'Tool wear [min]': '184', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '151', 'Product ID': 'L47330', 'Type': 'L', 'Air temperature [K]': '298.4', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1422', 'Torque [Nm]': '42.7', 'Tool wear [min]': '186', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '152', 'Product ID': 'M15011', 'Type': 'M', 'Air temperature [K]': '298.4', 'Process temperature [K]': '308.2', 'Rotational speed [rpm]': '1463', 'Torque [Nm]': '37.6', 'Tool wear [min]': '188', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '153', 'Product ID': 'M15012', 'Type': 'M', 'Air temperature [K]': '298.4', 'Process temperature [K]': '308.2', 'Rotational speed [rpm]': '1584', 'Torque [Nm]': '41', 'Tool wear [min]': '191', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '154', 'Product ID': 'L47333', 'Type': 'L', 'Air temperature [K]': '298.4', 'Process temperature [K]': '308.2', 'Rotational speed [rpm]': '1850', 'Torque [Nm]': '27', 'Tool wear [min]': '194', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '155', 'Product ID': 'L47334', 'Type': 'L', 'Air temperature [K]': '298.4', 'Process temperature [K]': '308.2', 'Rotational speed [rpm]': '1528', 'Torque [Nm]': '36.2', 'Tool wear [min]': '196', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '156', 'Product ID': 'H29569', 'Type': 'H', 'Air temperature [K]': '298.4', 'Process temperature [K]': '308.2', 'Rotational speed [rpm]': '1987', 'Torque [Nm]': '19.8', 'Tool wear [min]': '198', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '157', 'Product ID': 'M15016', 'Type': 'M', 'Air temperature [K]': '298.4', 'Process temperature [K]': '308.1', 'Rotational speed [rpm]': '1495', 'Torque [Nm]': '46', 'Tool wear [min]': '203', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '158', 'Product ID': 'H29571', 'Type': 'H', 'Air temperature [K]': '298.4', 'Process temperature [K]': '308.2', 'Rotational speed [rpm]': '1478', 'Torque [Nm]': '43.5', 'Tool wear [min]': '206', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '159', 'Product ID': 'M15018', 'Type': 'M', 'Air temperature [K]': '298.4', 'Process temperature [K]': '308.2', 'Rotational speed [rpm]': '1499', 'Torque [Nm]': '40', 'Tool wear [min]': '211', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '160', 'Product ID': 'L47339', 'Type': 'L', 'Air temperature [K]': '298.4', 'Process temperature [K]': '308.2', 'Rotational speed [rpm]': '1471', 'Torque [Nm]': '47', 'Tool wear [min]': '214', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '161', 'Product ID': 'L47340', 'Type': 'L', 'Air temperature [K]': '298.4', 'Process temperature [K]': '308.2', 'Rotational speed [rpm]': '1282', 'Torque [Nm]': '60.7', 'Tool wear [min]': '216', 'Target': '1', 'Failure Type': 'Overstrain Failure'}
# {'\ufeffUDI': '162', 'Product ID': 'L47341', 'Type': 'L', 'Air temperature [K]': '298.3', 'Process temperature [K]': '308.1', 'Rotational speed [rpm]': '1412', 'Torque [Nm]': '52.3', 'Tool wear [min]': '218', 'Target': '1', 'Failure Type': 'Overstrain Failure'}
# {'\ufeffUDI': '163', 'Product ID': 'L47342', 'Type': 'L', 'Air temperature [K]': '298.3', 'Process temperature [K]': '308.1', 'Rotational speed [rpm]': '1586', 'Torque [Nm]': '35.5', 'Tool wear [min]': '0', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '164', 'Product ID': 'M15023', 'Type': 'M', 'Air temperature [K]': '298.4', 'Process temperature [K]': '308.2', 'Rotational speed [rpm]': '1468', 'Torque [Nm]': '43.8', 'Tool wear [min]': '2', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '165', 'Product ID': 'M15024', 'Type': 'M', 'Air temperature [K]': '298.5', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1440', 'Torque [Nm]': '43.6', 'Tool wear [min]': '5', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '166', 'Product ID': 'L47345', 'Type': 'L', 'Air temperature [K]': '298.5', 'Process temperature [K]': '308.4', 'Rotational speed [rpm]': '1733', 'Torque [Nm]': '26', 'Tool wear [min]': '8', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '167', 'Product ID': 'H29580', 'Type': 'H', 'Air temperature [K]': '298.4', 'Process temperature [K]': '308.2', 'Rotational speed [rpm]': '1612', 'Torque [Nm]': '32.6', 'Tool wear [min]': '10', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '168', 'Product ID': 'H29581', 'Type': 'H', 'Air temperature [K]': '298.4', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1458', 'Torque [Nm]': '42.9', 'Tool wear [min]': '15', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '169', 'Product ID': 'L47348', 'Type': 'L', 'Air temperature [K]': '298.4', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1433', 'Torque [Nm]': '62.3', 'Tool wear [min]': '20', 'Target': '1', 'Failure Type': 'Power Failure'}
# {'\ufeffUDI': '170', 'Product ID': 'L47349', 'Type': 'L', 'Air temperature [K]': '298.4', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1318', 'Torque [Nm]': '59.1', 'Tool wear [min]': '22', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '171', 'Product ID': 'M15030', 'Type': 'M', 'Air temperature [K]': '298.4', 'Process temperature [K]': '308.2', 'Rotational speed [rpm]': '1610', 'Torque [Nm]': '35', 'Tool wear [min]': '24', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '172', 'Product ID': 'L47351', 'Type': 'L', 'Air temperature [K]': '298.2', 'Process temperature [K]': '308.1', 'Rotational speed [rpm]': '1462', 'Torque [Nm]': '50.8', 'Tool wear [min]': '27', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '173', 'Product ID': 'M15032', 'Type': 'M', 'Air temperature [K]': '298.1', 'Process temperature [K]': '308', 'Rotational speed [rpm]': '1924', 'Torque [Nm]': '20.8', 'Tool wear [min]': '29', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '174', 'Product ID': 'M15033', 'Type': 'M', 'Air temperature [K]': '298.2', 'Process temperature [K]': '308', 'Rotational speed [rpm]': '1591', 'Torque [Nm]': '33.7', 'Tool wear [min]': '32', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '175', 'Product ID': 'L47354', 'Type': 'L', 'Air temperature [K]': '298.2', 'Process temperature [K]': '308.1', 'Rotational speed [rpm]': '1306', 'Torque [Nm]': '58.3', 'Tool wear [min]': '35', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '176', 'Product ID': 'L47355', 'Type': 'L', 'Air temperature [K]': '298.2', 'Process temperature [K]': '308.1', 'Rotational speed [rpm]': '1382', 'Torque [Nm]': '43.5', 'Tool wear [min]': '37', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '177', 'Product ID': 'L47356', 'Type': 'L', 'Air temperature [K]': '298.2', 'Process temperature [K]': '308.1', 'Rotational speed [rpm]': '1618', 'Torque [Nm]': '34.7', 'Tool wear [min]': '39', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '178', 'Product ID': 'L47357', 'Type': 'L', 'Air temperature [K]': '298.2', 'Process temperature [K]': '308.2', 'Rotational speed [rpm]': '1988', 'Torque [Nm]': '21.4', 'Tool wear [min]': '41', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '179', 'Product ID': 'L47358', 'Type': 'L', 'Air temperature [K]': '298.2', 'Process temperature [K]': '308.2', 'Rotational speed [rpm]': '1436', 'Torque [Nm]': '50.2', 'Tool wear [min]': '43', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '180', 'Product ID': 'L47359', 'Type': 'L', 'Air temperature [K]': '298.2', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1304', 'Torque [Nm]': '49.8', 'Tool wear [min]': '45', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '181', 'Product ID': 'L47360', 'Type': 'L', 'Air temperature [K]': '298.2', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1475', 'Torque [Nm]': '49.9', 'Tool wear [min]': '47', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '182', 'Product ID': 'H29595', 'Type': 'H', 'Air temperature [K]': '298.2', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1824', 'Torque [Nm]': '24.2', 'Tool wear [min]': '49', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '183', 'Product ID': 'M15042', 'Type': 'M', 'Air temperature [K]': '298.1', 'Process temperature [K]': '308.2', 'Rotational speed [rpm]': '1342', 'Torque [Nm]': '48.1', 'Tool wear [min]': '54', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '184', 'Product ID': 'L47363', 'Type': 'L', 'Air temperature [K]': '298.1', 'Process temperature [K]': '308.2', 'Rotational speed [rpm]': '1485', 'Torque [Nm]': '40.7', 'Tool wear [min]': '57', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '185', 'Product ID': 'L47364', 'Type': 'L', 'Air temperature [K]': '298.2', 'Process temperature [K]': '308.2', 'Rotational speed [rpm]': '1667', 'Torque [Nm]': '30.6', 'Tool wear [min]': '59', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '186', 'Product ID': 'L47365', 'Type': 'L', 'Air temperature [K]': '298.2', 'Process temperature [K]': '308.2', 'Rotational speed [rpm]': '1446', 'Torque [Nm]': '38.2', 'Tool wear [min]': '61', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '187', 'Product ID': 'L47366', 'Type': 'L', 'Air temperature [K]': '298.1', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1301', 'Torque [Nm]': '56', 'Tool wear [min]': '63', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '188', 'Product ID': 'L47367', 'Type': 'L', 'Air temperature [K]': '298.2', 'Process temperature [K]': '308.4', 'Rotational speed [rpm]': '1379', 'Torque [Nm]': '43.1', 'Tool wear [min]': '65', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '189', 'Product ID': 'L47368', 'Type': 'L', 'Air temperature [K]': '298.3', 'Process temperature [K]': '308.5', 'Rotational speed [rpm]': '1606', 'Torque [Nm]': '33.6', 'Tool wear [min]': '67', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '190', 'Product ID': 'M15049', 'Type': 'M', 'Air temperature [K]': '298.3', 'Process temperature [K]': '308.4', 'Rotational speed [rpm]': '1539', 'Torque [Nm]': '43.4', 'Tool wear [min]': '69', 'Target': '0', 'Failure Type': 'No Failure'}
# ...
# {'\ufeffUDI': '317', 'Product ID': 'L47496', 'Type': 'L', 'Air temperature [K]': '297.8', 'Process temperature [K]': '308.4', 'Rotational speed [rpm]': '1714', 'Torque [Nm]': '33.2', 'Tool wear [min]': '177', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '318', 'Product ID': 'L47497', 'Type': 'L', 'Air temperature [K]': '297.8', 'Process temperature [K]': '308.4', 'Rotational speed [rpm]': '1685', 'Torque [Nm]': '28.4', 'Tool wear [min]': '179', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '319', 'Product ID': 'L47498', 'Type': 'L', 'Air temperature [K]': '297.8', 'Process temperature [K]': '308.4', 'Rotational speed [rpm]': '1512', 'Torque [Nm]': '39.9', 'Tool wear [min]': '181', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '320', 'Product ID': 'L47499', 'Type': 'L', 'Air temperature [K]': '297.8', 'Process temperature [K]': '308.4', 'Rotational speed [rpm]': '1612', 'Torque [Nm]': '32.1', 'Tool wear [min]': '183', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '321', 'Product ID': 'H29734', 'Type': 'H', 'Air temperature [K]': '297.8', 'Process temperature [K]': '308.4', 'Rotational speed [rpm]': '1550', 'Torque [Nm]': '38.2', 'Tool wear [min]': '185', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '322', 'Product ID': 'L47501', 'Type': 'L', 'Air temperature [K]': '297.8', 'Process temperature [K]': '308.4', 'Rotational speed [rpm]': '1518', 'Torque [Nm]': '32.5', 'Tool wear [min]': '190', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '323', 'Product ID': 'L47502', 'Type': 'L', 'Air temperature [K]': '297.8', 'Process temperature [K]': '308.5', 'Rotational speed [rpm]': '1448', 'Torque [Nm]': '40', 'Tool wear [min]': '192', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '324', 'Product ID': 'L47503', 'Type': 'L', 'Air temperature [K]': '297.8', 'Process temperature [K]': '308.5', 'Rotational speed [rpm]': '1561', 'Torque [Nm]': '46.3', 'Tool wear [min]': '194', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '325', 'Product ID': 'M15184', 'Type': 'M', 'Air temperature [K]': '297.8', 'Process temperature [K]': '308.5', 'Rotational speed [rpm]': '1488', 'Torque [Nm]': '41.9', 'Tool wear [min]': '196', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '326', 'Product ID': 'L47505', 'Type': 'L', 'Air temperature [K]': '297.8', 'Process temperature [K]': '308.5', 'Rotational speed [rpm]': '1699', 'Torque [Nm]': '27.8', 'Tool wear [min]': '199', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '327', 'Product ID': 'L47506', 'Type': 'L', 'Air temperature [K]': '297.7', 'Process temperature [K]': '308.5', 'Rotational speed [rpm]': '1501', 'Torque [Nm]': '41.4', 'Tool wear [min]': '201', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '328', 'Product ID': 'L47507', 'Type': 'L', 'Air temperature [K]': '297.7', 'Process temperature [K]': '308.5', 'Rotational speed [rpm]': '1373', 'Torque [Nm]': '56.7', 'Tool wear [min]': '203', 'Target': '1', 'Failure Type': 'Overstrain Failure'}
# {'\ufeffUDI': '329', 'Product ID': 'H29742', 'Type': 'H', 'Air temperature [K]': '297.6', 'Process temperature [K]': '308.4', 'Rotational speed [rpm]': '1703', 'Torque [Nm]': '31.4', 'Tool wear [min]': '205', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '330', 'Product ID': 'H29743', 'Type': 'H', 'Air temperature [K]': '297.7', 'Process temperature [K]': '308.5', 'Rotational speed [rpm]': '1720', 'Torque [Nm]': '29.9', 'Tool wear [min]': '210', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '331', 'Product ID': 'M15190', 'Type': 'M', 'Air temperature [K]': '297.6', 'Process temperature [K]': '308.4', 'Rotational speed [rpm]': '1398', 'Torque [Nm]': '41.9', 'Tool wear [min]': '215', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '332', 'Product ID': 'M15191', 'Type': 'M', 'Air temperature [K]': '297.6', 'Process temperature [K]': '308.4', 'Rotational speed [rpm]': '1391', 'Torque [Nm]': '51.9', 'Tool wear [min]': '218', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '333', 'Product ID': 'M15192', 'Type': 'M', 'Air temperature [K]': '297.6', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1538', 'Torque [Nm]': '40.2', 'Tool wear [min]': '0', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '334', 'Product ID': 'L47513', 'Type': 'L', 'Air temperature [K]': '297.5', 'Process temperature [K]': '308.2', 'Rotational speed [rpm]': '1647', 'Torque [Nm]': '31.3', 'Tool wear [min]': '3', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '335', 'Product ID': 'M15194', 'Type': 'M', 'Air temperature [K]': '297.5', 'Process temperature [K]': '308.1', 'Rotational speed [rpm]': '1469', 'Torque [Nm]': '44.8', 'Tool wear [min]': '5', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '336', 'Product ID': 'L47515', 'Type': 'L', 'Air temperature [K]': '297.4', 'Process temperature [K]': '308.1', 'Rotational speed [rpm]': '1749', 'Torque [Nm]': '25.9', 'Tool wear [min]': '8', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '337', 'Product ID': 'M15196', 'Type': 'M', 'Air temperature [K]': '297.6', 'Process temperature [K]': '308.2', 'Rotational speed [rpm]': '1995', 'Torque [Nm]': '20.5', 'Tool wear [min]': '10', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '338', 'Product ID': 'L47517', 'Type': 'L', 'Air temperature [K]': '297.6', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1742', 'Torque [Nm]': '27.7', 'Tool wear [min]': '13', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '339', 'Product ID': 'L47518', 'Type': 'L', 'Air temperature [K]': '297.5', 'Process temperature [K]': '308.2', 'Rotational speed [rpm]': '1563', 'Torque [Nm]': '38.2', 'Tool wear [min]': '15', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '340', 'Product ID': 'M15199', 'Type': 'M', 'Air temperature [K]': '297.5', 'Process temperature [K]': '308.2', 'Rotational speed [rpm]': '1713', 'Torque [Nm]': '32.2', 'Tool wear [min]': '17', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '341', 'Product ID': 'L47520', 'Type': 'L', 'Air temperature [K]': '297.4', 'Process temperature [K]': '308.1', 'Rotational speed [rpm]': '1474', 'Torque [Nm]': '39.4', 'Tool wear [min]': '20', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '342', 'Product ID': 'M15201', 'Type': 'M', 'Air temperature [K]': '297.4', 'Process temperature [K]': '308.2', 'Rotational speed [rpm]': '1530', 'Torque [Nm]': '32.6', 'Tool wear [min]': '22', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '343', 'Product ID': 'L47522', 'Type': 'L', 'Air temperature [K]': '297.4', 'Process temperature [K]': '308.2', 'Rotational speed [rpm]': '1471', 'Torque [Nm]': '46.5', 'Tool wear [min]': '25', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '344', 'Product ID': 'L47523', 'Type': 'L', 'Air temperature [K]': '297.5', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1388', 'Torque [Nm]': '48.6', 'Tool wear [min]': '27', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '345', 'Product ID': 'M15204', 'Type': 'M', 'Air temperature [K]': '297.5', 'Process temperature [K]': '308.2', 'Rotational speed [rpm]': '2448', 'Torque [Nm]': '13.8', 'Tool wear [min]': '29', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '346', 'Product ID': 'L47525', 'Type': 'L', 'Air temperature [K]': '297.5', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1585', 'Torque [Nm]': '32.9', 'Tool wear [min]': '32', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '347', 'Product ID': 'M15206', 'Type': 'M', 'Air temperature [K]': '297.5', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1459', 'Torque [Nm]': '45.2', 'Tool wear [min]': '34', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '348', 'Product ID': 'L47527', 'Type': 'L', 'Air temperature [K]': '297.5', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1544', 'Torque [Nm]': '40.8', 'Tool wear [min]': '37', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '349', 'Product ID': 'L47528', 'Type': 'L', 'Air temperature [K]': '297.6', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1617', 'Torque [Nm]': '31.7', 'Tool wear [min]': '39', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '350', 'Product ID': 'L47529', 'Type': 'L', 'Air temperature [K]': '297.6', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1595', 'Torque [Nm]': '34.3', 'Tool wear [min]': '41', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '351', 'Product ID': 'H29764', 'Type': 'H', 'Air temperature [K]': '297.6', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1400', 'Torque [Nm]': '44.3', 'Tool wear [min]': '43', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '352', 'Product ID': 'M15211', 'Type': 'M', 'Air temperature [K]': '297.6', 'Process temperature [K]': '308.4', 'Rotational speed [rpm]': '1611', 'Torque [Nm]': '31', 'Tool wear [min]': '48', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '353', 'Product ID': 'M15212', 'Type': 'M', 'Air temperature [K]': '297.6', 'Process temperature [K]': '308.4', 'Rotational speed [rpm]': '1507', 'Torque [Nm]': '46', 'Tool wear [min]': '51', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '354', 'Product ID': 'H29767', 'Type': 'H', 'Air temperature [K]': '297.5', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1674', 'Torque [Nm]': '30', 'Tool wear [min]': '54', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '355', 'Product ID': 'L47534', 'Type': 'L', 'Air temperature [K]': '297.6', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1658', 'Torque [Nm]': '34.3', 'Tool wear [min]': '59', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '356', 'Product ID': 'L47535', 'Type': 'L', 'Air temperature [K]': '297.6', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1623', 'Torque [Nm]': '36.9', 'Tool wear [min]': '61', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '357', 'Product ID': 'M15216', 'Type': 'M', 'Air temperature [K]': '297.6', 'Process temperature [K]': '308.4', 'Rotational speed [rpm]': '1398', 'Torque [Nm]': '48.9', 'Tool wear [min]': '63', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '358', 'Product ID': 'L47537', 'Type': 'L', 'Air temperature [K]': '297.6', 'Process temperature [K]': '308.4', 'Rotational speed [rpm]': '1517', 'Torque [Nm]': '34.2', 'Tool wear [min]': '66', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '359', 'Product ID': 'M15218', 'Type': 'M', 'Air temperature [K]': '297.6', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1467', 'Torque [Nm]': '36.7', 'Tool wear [min]': '68', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '360', 'Product ID': 'M15219', 'Type': 'M', 'Air temperature [K]': '297.6', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1567', 'Torque [Nm]': '34.6', 'Tool wear [min]': '71', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '361', 'Product ID': 'M15220', 'Type': 'M', 'Air temperature [K]': '297.5', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1521', 'Torque [Nm]': '38.2', 'Tool wear [min]': '74', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '362', 'Product ID': 'L47541', 'Type': 'L', 'Air temperature [K]': '297.5', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1596', 'Torque [Nm]': '36.8', 'Tool wear [min]': '77', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '363', 'Product ID': 'H29776', 'Type': 'H', 'Air temperature [K]': '297.6', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1640', 'Torque [Nm]': '30.9', 'Tool wear [min]': '79', 'Target': '0', 'Failure Type': 'No Failure'}
# {'\ufeffUDI': '364', 'Product ID': 'L47543', 'Type': 'L', 'Air temperature [K]': '297.6', 'Process temperature [K]': '308.3', 'Rotational speed [rpm]': '1438', 'Torque [Nm]': '47.8', 'Tool wear [min]': '84', 'Target': '0', 'Failure Type': 'No Failure'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 18
#       6 collection = client.numtest.numtest
#       8 consumer = KafkaConsumer(
#       9     'Data_MachineIOT',
#      10      bootstrap_servers=['localhost:9092'],
#    (...)
#      13     # group_id='IotData',
#      14      value_deserializer=lambda x: loads(x.decode('utf-8')))
# ---> 18 for message in consumer:
#      19     message1 = message.value
#      20     #collection.insert_one(message)
#
# File ~/.local/lib/python3.9/site-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File ~/.local/lib/python3.9/site-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File ~/.local/lib/python3.9/site-packages/kafka/consumer/group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File ~/.local/lib/python3.9/site-packages/kafka/consumer/group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File ~/.local/lib/python3.9/site-packages/kafka/consumer/group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File ~/.local/lib/python3.9/site-packages/kafka/client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File ~/.local/lib/python3.9/site-packages/kafka/client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File /usr/lib/python3.9/selectors.py:469, in EpollSelector.select(self, timeout)
#     467 ready = []
#     468 try:
# --> 469     fd_event_list = self._selector.poll(timeout, max_ev)
#     470 except InterruptedError:
#     471     return ready
#
# KeyboardInterrupt:

# %%
print(collection)
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest'), 'numtest')

# %%
pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.3.3-cp39-cp39-manylinux2014_x86_64.whl (509 kB)
#      |████████████████████████████████| 509 kB 487 kB/s eta 0:00:01
# Collecting dnspython<3.0.0,>=1.16.0
#   Downloading dnspython-2.2.1-py3-none-any.whl (269 kB)
#      |████████████████████████████████| 269 kB 1.3 MB/s eta 0:00:01
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.2.1 pymongo-4.3.3
# Note: you may need to restart the kernel to use updated packages.
